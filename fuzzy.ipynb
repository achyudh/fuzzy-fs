# %%
import numpy as np
import matplotlib.pyplot as plt
import skfuzzy as fuzz
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics
from sklearn.model_selection import train_test_split
from skcmeans.algorithms import Probabilistic
from sklearn.datasets import make_blobs

# %%
data = pd.read_table("data/20NG/training.txt") 
data.columns=["Y","X"]
# import sys
# sys.stdout = open('a.txt', 'w')

# %% [markdown]
# # Returns a Dataframe with five random classes

# %%
def ran5class(data):
    classes = ['alt.atheism',
                 'comp.graphics',
                 'comp.os.ms-windows.misc',
                 'comp.sys.ibm.pc.hardware',
                 'comp.sys.mac.hardware',
                 'comp.windows.x',
                 'misc.forsale',
                 'rec.autos',
                 'rec.motorcycles',
                 'rec.sport.baseball',
                 'rec.sport.hockey',
                 'sci.crypt',
                 'sci.electronics',
                 'sci.med',
                 'sci.space',
                 'soc.religion.christian',
                 'talk.politics.guns',
                 'talk.politics.mideast',
                 'talk.politics.misc',
                 'talk.religion.misc']
    np.random.shuffle(classes)

    group5 = data.loc[data['Y'] == classes[0]]
    group5 = group5.append(data.loc[data['Y'] == classes[1]], ignore_index=True)
    group5 = group5.append(data.loc[data['Y'] == classes[2]], ignore_index=True)
    group5 = group5.append(data.loc[data['Y'] == classes[3]], ignore_index=True)
    return group5.append(data.loc[data['Y'] == classes[4]], ignore_index=True)

# %%
# group5 = ran5class(data)

Y = data["Y"]
X = data["X"]

# x_train, X, y_train, Y = train_test_split(
#     X, Y, test_size=0.001)

vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(X).toarray()

x_train, x_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.2)

# %%
print(X.shape)
print(y_train.shape)
# Out:
# (11292, 73626)
# (9033,)

# %%
cntr, u, u0, d, jm, p, fpc = fuzz.cluster.cmeans(
        x_train, 20, 2, error=0.005, maxiter=1000, init=None)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-22-32675d75b90a> in <module>()
#       1 cntr, u, u0, d, jm, p, fpc = fuzz.cluster.cmeans(
# ----> 2         x_train, 20, 2, error=0.005, maxiter=1000, init=None)
#
# /home/a/workspace/venv/lib/python3.5/site-packages/skfuzzy/cluster/_cmeans.py in cmeans(data, c, m, error, maxiter, init, seed)
#     165     while p < maxiter - 1:
#     166         u2 = u.copy()
# --> 167         [cntr, u, Jjm, d] = _cmeans0(data, u2, c, m)
#     168         jm = np.hstack((jm, Jjm))
#     169         p += 1
#
# /home/a/workspace/venv/lib/python3.5/site-packages/skfuzzy/cluster/_cmeans.py in _cmeans0(data, u_old, c, m)
#      26                                     1)).dot(np.atleast_2d(um.sum(axis=1))).T)
#      27
# ---> 28     d = _distance(data, cntr)
#      29     d = np.fmax(d, np.finfo(np.float64).eps)
#      30
#
# /home/a/workspace/venv/lib/python3.5/site-packages/skfuzzy/cluster/_cmeans.py in _distance(data, centers)
#      57     scipy.spatial.distance.cdist
#      58     """
# ---> 59     return cdist(data, centers).T
#      60
#      61
#
# /home/a/workspace/venv/lib/python3.5/site-packages/scipy/spatial/distance.py in cdist(XA, XB, metric, p, V, VI, w)
#    2014     # but with a more succinct, verifiable, but less efficient implementation.
#    2015
# -> 2016     XA = np.asarray(XA, order='c')
#    2017     XB = np.asarray(XB, order='c')
#    2018
#
# /home/a/workspace/venv/lib/python3.5/site-packages/numpy/core/numeric.py in asarray(a, dtype, order)
#     529
#     530     """
# --> 531     return array(a, dtype, copy=False, order=order)
#     532
#     533
#
# MemoryError:

# %%
classes
# Out:
# {'alt.atheism': 478,
#  'comp.graphics': 1062,
#  'comp.os.ms-windows.misc': 1634,
#  'comp.sys.ibm.pc.hardware': 2224,
#  'comp.sys.mac.hardware': 2802,
#  'comp.windows.x': 3395,
#  'misc.forsale': 3980,
#  'rec.autos': 4574,
#  'rec.motorcycles': 5172,
#  'rec.sport.baseball': 5769,
#  'rec.sport.hockey': 6369,
#  'sci.crypt': 6964,
#  'sci.electronics': 7555,
#  'sci.med': 8149,
#  'sci.space': 8742,
#  'soc.religion.christian': 9340,
#  'talk.politics.guns': 9885,
#  'talk.politics.mideast': 10449,
#  'talk.politics.misc': 10914,
#  'talk.religion.misc': 11291}

# %%
group5.loc[group5['Y'] == 'comp.os.ms-windows.misc']
# Out:
#                             Y  \
# 1063  comp.os.ms-windows.misc
# 1064  comp.os.ms-windows.misc
# 1065  comp.os.ms-windows.misc
# 1066  comp.os.ms-windows.misc
# 1067  comp.os.ms-windows.misc
# 1068  comp.os.ms-windows.misc
# 1069  comp.os.ms-windows.misc
# 1070  comp.os.ms-windows.misc
# 1071  comp.os.ms-windows.misc
# 1072  comp.os.ms-windows.misc
# 1073  comp.os.ms-windows.misc
# 1074  comp.os.ms-windows.misc
# 1075  comp.os.ms-windows.misc
# 1076  comp.os.ms-windows.misc
# 1077  comp.os.ms-windows.misc
# 1078  comp.os.ms-windows.misc
# 1079  comp.os.ms-windows.misc
# 1080  comp.os.ms-windows.misc
# 1081  comp.os.ms-windows.misc
# 1082  comp.os.ms-windows.misc
# 1083  comp.os.ms-windows.misc
# 1084  comp.os.ms-windows.misc
# 1085  comp.os.ms-windows.misc
# 1086  comp.os.ms-windows.misc
# 1087  comp.os.ms-windows.misc
# 1088  comp.os.ms-windows.misc
# 1089  comp.os.ms-windows.misc
# 1090  comp.os.ms-windows.misc
# 1091  comp.os.ms-windows.misc
# 1092  comp.os.ms-windows.misc
# ...                       ...
# 1605  comp.os.ms-windows.misc
# 1606  comp.os.ms-windows.misc
# 1607  comp.os.ms-windows.misc
# 1608  comp.os.ms-windows.misc
# 1609  comp.os.ms-windows.misc
# 1610  comp.os.ms-windows.misc
# 1611  comp.os.ms-windows.misc
# 1612  comp.os.ms-windows.misc
# 1613  comp.os.ms-windows.misc
# 1614  comp.os.ms-windows.misc
# 1615  comp.os.ms-windows.misc
# 1616  comp.os.ms-windows.misc
# 1617  comp.os.ms-windows.misc
# 1618  comp.os.ms-windows.misc
# 1619  comp.os.ms-windows.misc
# 1620  comp.os.ms-windows.misc
# 1621  comp.os.ms-windows.misc
# 1622  comp.os.ms-windows.misc
# 1623  comp.os.ms-windows.misc
# 1624  comp.os.ms-windows.misc
# 1625  comp.os.ms-windows.misc
# 1626  comp.os.ms-windows.misc
# 1627  comp.os.ms-windows.misc
# 1628  comp.os.ms-windows.misc
# 1629  comp.os.ms-windows.misc
# 1630  comp.os.ms-windows.misc
# 1631  comp.os.ms-windows.misc
# 1632  comp.os.ms-windows.misc
# 1633  comp.os.ms-windows.misc
# 1634  comp.os.ms-windows.misc
#
#                                                       X
# 1063  re is kermit available for windows from articl...
# 1064  win storm pc anyone have any info on the video...
# 1065  re win doublespace in article hpwala wal hp co...
# 1066  ms mouse driver does anyone have the documenta...
# 1067  win icon help please i have win and downloaded...
# 1068  is smartdrv exe causing bad sectors on my hd i...
# 1069  re ms windows access for the blind in apr seas...
# 1070  why i m not using dos anymore i ve been runnin...
# 1071  help with changing startup logo hello brad mon...
# 1072  where to get ati card video drivers fonts does...
# 1073  truetype oem font with line drawing characters...
# 1074  re help with changing startup logo in article ...
# 1075  re document of rtf in article mar worak kaist ...
# 1076  re winbench help graphics comparison in articl...
# 1077  re does dos defragment geoffrey s elbo writes ...
# 1078  re windows gripe there s one thing about windo...
# 1079  re winbench jorge erex east sun com jorge lach...
# 1080  re norton desktop for windows in article apr e...
# 1081  re does dos defragment in article c h m p news...
# 1082  re pc geos windows os and unix x in sehari vin...
# 1083  comments on xtree for windows i am looking for...
# 1084  re is microsoft windows really and ope all ico...
# 1085  re is microsoft windows really and operating s...
# 1086  sound blaster ver under windows article crossp...
# 1087  re windows gripe in article ppmvf qnh bigboote...
# 1088  re atm or truetype which to choose in article ...
# 1089  re does dos defragment in article apr cs brown...
# 1090  re pc geos windows os and unix x in article se...
# 1091  re windows on a ramdrive help f langleyrh ccsv...
# 1092  re pc geos windows os and unix x in article c ...
# ...                                                 ...
# 1605  re telephone of cirrus logic in article c m s ...
# 1606  re program manager two questions in apr vpnet ...
# 1607  re drivers for stealth doug ward writes i rece...
# 1608  mouse jumpiness solved can t guarantee that it...
# 1609  is kermit available for windows hello all i wa...
# 1610  re summary borland microsoft database c librar...
# 1611  win nt file systems ok will some one out there...
# 1612  mail order sales billing receivables program s...
# 1613  re ami pro and pctools compress doesn t like b...
# 1614  re workspace managers for win a small review c...
# 1615  dos w wg problem i am running windows windows ...
# 1616  re canon bj bubblejet and hp deskjet in articl...
# 1617  for sale borland c w application frameworks pl...
# 1618  strange enhanced behavior howdy we have been h...
# 1619  re why is my mouse so jumpy ms mouse ecktons u...
# 1620              re winqvtnet with ndis on token ring
# 1621  re more diamond ss x dil admin mhs unc edu dav...
# 1622  what does the bmp format mean what exactly doe...
# 1623  dll s and registerclass createwindow hi all i ...
# 1624  roman bmp in response to the requests for cool...
# 1625  stealth video drivers i recently purchased a d...
# 1626  netware win fileman is there a update or somet...
# 1627  re bbbbig problem with w w print file help in ...
# 1628  re tidying up after removing an ole server in ...
# 1629  re win nt file systems in article apr spider c...
# 1630  re viewsonic experience sought vs vs nec fg i ...
# 1631  rfd comp os ms windows nt misc setup this is t...
# 1632  dde frustrations can you help i am starting to...
# 1633  dos window macros does anyone know a program t...
# 1634  adobe and adobe i wanted to create a postcript...
#
# [572 rows x 2 columns]
